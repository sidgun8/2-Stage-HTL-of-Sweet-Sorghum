# %%
import biosteam as bst
import thermosteam as tmo

# %%
from biosteam import settings

# %%
from biosteam import Unit, Stream, settings, main_flowsheet
import biosteam as bst
bst.nbtutorial() # Light-mode html diagrams and filter warnings
settings.set_thermo(['Water'])
ins = Stream('in0')
outs = [Stream('out0')]
U1 = Unit(ID='U1', ins=ins, outs=outs)
U1.show(data=False) # Passing data as False returns only stream names
# Out:
# Unit: U1
# ins...
# [0] in0
# outs...
# [0] out0

# %%
bst.settings.set_thermo(['Water', 'He','CO2','Cellulose','Hemicellulose','Lignin','Ash','Glucose','Xylose','Arabinose','Sucrose','Fructose','Furfural','Acetic Acid','Formic Acid','H2SO4'],db='BioSTEAM')

# %%
from biosteam import units
import numpy as np

bst.main_flowsheet.set_flowsheet('sugarcane_ethanol')

# We can create streams and set component splits faster by defining chemical groups
chemicals = bst.settings.chemicals
chemicals.define_group(
    name='Fiber',
    IDs=['Cellulose', 'Hemicellulose', 'Lignin'],
    composition=[0.4704 , 0.2775, 0.2520],
    wt=True, # Composition is given as weight
)
chemicals.define_group(
    name='Sugar',
    IDs=['Sucrose', 'Glucose'],
    # Default composition as equimolar
)

sugarcane = bst.Stream(
    'sugarcane',
    Water=0.7,
    Glucose=0.01208,
    Sucrose=0.1369,
    Ash=0.006,
    Fiber=0.13,
    Solids=0.015,
    total_flow=370396,
    units='kg/hr',
    price=price['Sugar cane']
)

enzyme = bst.Stream('enzyme',
                    Cellulose=100, Water=900, units='kg/hr',
                    price=price['Protease'])

imbibition_water = bst.Stream('imbibition_water',
                              Water=87023.35, units='kg/hr',
                              T = 338.15)

H3PO4 = bst.Stream('H3PO4',
                   H3PO4=74.23, Water=13.10, units='kg/hr',
                   price=price['H3PO4'])  # to T203

lime = bst.Stream('lime',
                  CaO=333.00, Water=2200.00, units='kg/hr',
                  price=price['Lime'])  # to P5

polymer = bst.Stream('polymer',
                     Flocculant=0.83, units='kg/hr',
                     price=price['Polymer'])  # to T205

rvf_wash_water = bst.Stream('rvf_wash_water',
                            Water=16770, units='kg/hr',
                            T=363.15)  # to C202

### Unit operations ###

# Feed from storage
U101 = units.ConveyingBelt('U101', sugarcane)

# Separate metals
U102 = units.MagneticSeparator('U102', U101-0)

# Shredded cane
U103 = units.Shredder('U103', U102-0)

# Hydrolyze starch
T201 = units.EnzymeTreatment('T201', [U103-0, enzyme], T=323.15)  # T=50

# Finely crush lipid cane
imbibition_water_recycle = bst.Stream() # To connect later
U201 = units.CrushingMill('U201', [T201-0, imbibition_water_recycle],
                          split=dict(Ash=0.92,
                                     Fiber=0.92,
                                     Sugar=0.04,
                                     Solids=1),
                          moisture_content=0.5)

# Convey out bagasse
U202 = units.ConveyingBelt('U202', U201-0, outs='Bagasse')

# Screen out fibers
S201 = units.VibratingScreen('S201', U201-1,
                             split=dict(Ash=0.35,
                                        Fiber=0.35,
                                        Sugar=0.88,
                                        Water=0.88,
                                        Solids=0))

# Mix in water
M201 = units.Mixer('M201', [S201-1, imbibition_water], imbibition_water_recycle)

# Store juice before treatment
T202 = units.StorageTank('T202', S201-0, tau=4, vessel_material='Carbon steel')

# Heat up before adding acid
H201 = units.HXutility('H201', T202-0, T=343.15)

# Mix in acid
T203 = units.MixTank('T203', [H201-0, H3PO4])

# Pump acid solution
P201 = units.Pump('P201', T203-0)

# Mix lime solution
T204 = units.MixTank('T204', [P201-0, lime], tau=0.10)

# Blend acid lipid solution with lime
T205 = units.MixTank('T205', T204-0, tau=0.10)
P202 = units.Pump('P202', T205-0)

# Mix recycle
RVF_recycle = bst.Stream() # From rotary vacuum filter; connect later
M202 = units.Mixer('M202', [P202-0, RVF_recycle])

# Heat before adding flocculant
H202 = units.HXutility('H202', M202-0, T=372.15)

# Mix in flocculant
T206 = units.MixTank('T206', [H202-0, polymer])
T206.tau = 0.10

# Separate residual solids
C201 = units.Clarifier('C201', T206-0,
                       split=dict(Ash=0,
                                  CaO=0,
                                  Fiber=0,
                                  Flocculant=0.522,
                                  Sugar=0.522,
                                  H3PO4=0.522,
                                  Water=0.522))

# Remove solids as filter cake
C202 = units.RVF('C202', [C201-1, rvf_wash_water],
                 outs=('filter_cake', ''),
                 moisture_content=0.80,
                 split=dict(Ash=0.85,
                            CaO=0.85,
                            Fiber=0.85,
                            Sugar=0.01))
P203 = units.Pump('P203', C202-1, RVF_recycle)


# Screen out small fibers from sugar stream
S202 = units.VibratingScreen('S202', C201-0,
                             outs=('', 'fiber_fines'),
                             split=dict(Ash=1.0,
                                        CaO=1.0,
                                        Fiber=1.0,
                                        Flocculant=0.0,
                                        Sugar=0.998,
                                        H3PO4=1.0,
                                        Water=0.998))
S202.mesh_opening = 2

### Process specifications ###

# Specifications dependent on lipid cane flow rate
@U103.add_specification(run=True) # Run unit operation afterwords
def correct_flows():
    feedstock = U101.ins[0]
    F_mass = feedstock.F_mass
    # correct enzyme, lime, phosphoric acid, and imbibition water
    enzyme.imass['Cellulose', 'Water'] = 0.003 * F_mass * np.array([0.1, 0.9])
    lime.imass['CaO', 'Water'] = 0.001 * F_mass * np.array([0.046, 0.954])
    H3PO4.imass['H3PO4', 'Water'] = 0.00025 * F_mass
    imbibition_water.imass['Water'] = 0.25* F_mass

# Specifications within a system
@P202.add_specification(run=True)
def correct_wash_water():
    solids = P202.ins[0].imol['Ash', 'CaO', 'Fiber'].sum()
    rvf_wash_water.imol['Water'] = 0.0574 * solids

bst.main_flowsheet.diagram(format='png') # Flow sheet up until now

# %%
# example for 1 kg feed basis (adjust as needed)
bagasse_slurry = bst.Stream(
    'bagasse_slurry',
    Water=0.88,           # majority is water (slurry), set correct kg/hr
    Cellulose=0.03617,    # (36.17 wt% of dry biomass; scale to slurry basis)
    Hemicellulose=0.01968,
    Lignin=0.01766,
    Ash=0.00459,
    Sucrose=0.01155*0.1605,  # optional split: paper quotes soluble sugar breakdown; adjust
    Glucose=0.01155*0.4937,
    Fructose=0.01155*0.3458,
    units='kg/hr'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/_chemicals.py:1259, in CompiledChemicals._get_index_and_kind(self, key)
#    1258     if key.__hash__ is None: key = tuple(key)
# -> 1259     return index_cache[key]
#    1260 except KeyError:
#
# KeyError: ('Water', 'Cellulose', 'Hemicellulose', 'Lignin', 'Ash', 'Sucrose', 'Glucose', 'Fructose')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/_chemicals.py:1175, in CompiledChemicals.indices(self, IDs)
#    1174 try:
# -> 1175     return [dct[i] for i in IDs]
#    1176 except KeyError as key_error:
#
# KeyError: 'Cellulose'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedChemicalAlias                    Traceback (most recent call last)
# Cell In[9], line 2
#       1 # example for 1 kg feed basis (adjust as needed)
# ----> 2 bagasse_slurry = bst.Stream(
#       3     'bagasse_slurry',
#       4     Water=0.88,           # majority is water (slurry), set correct kg/hr
#       5     Cellulose=0.03617,    # (36.17 wt% of dry biomass; scale to slurry basis)
#       6     Hemicellulose=0.01968,
#       7     Lignin=0.01766,
#       8     Ash=0.00459,
#       9     Sucrose=0.01155*0.1605,  # optional split: paper quotes soluble sugar breakdown; adjust
#      10     Glucose=0.01155*0.4937,
#      11     Fructose=0.01155*0.3458,
#      12     units='kg/hr'
#      13 )
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/_stream.py:389, in Stream.__init__(self, ID, flow, phase, T, P, units, price, total_flow, thermo, characterization_factors, vlle, **chemical_flows)
#     386         if cID in group_wt_compositions:
#     387             raise ValueError(
#     388                 f"cannot set volumetric flow by chemical group '{i}'")
# --> 389 self._init_indexer(flow, phase, chemicals, chemical_flows)
#     390 mol = self.mol
#     391 flow = getattr(self, name)
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/_stream.py:891, in Stream._init_indexer(self, flow, phase, chemicals, chemical_flows)
#     889 parent = indexer.parent_indexer(chemicals)
#     890 if chemical_flows:
# --> 891     imol = indexer.ChemicalMolarFlowIndexer(
#     892         phase, chemicals=chemicals, parent=parent, **chemical_flows)
#     893 else:
#     894     imol = indexer.ChemicalMolarFlowIndexer.blank(
#     895         phase, chemicals, parent=parent)
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/indexer.py:521, in ChemicalIndexer.__new__(cls, phase, units, chemicals, parent, lock_phase, **ID_data)
#     519     IDs = tuple(ID_data)
#     520     values = list(ID_data.values())
# --> 521     self[IDs] = values
#     522     if units: self.set_data(self.data, units)
#     523 return self
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/indexer.py:544, in ChemicalIndexer.__setitem__(self, key, data)
#     543 def __setitem__(self, key, data):
# --> 544     index, kind = self._chemicals._get_index_and_kind(key)
#     545     if kind is None:
#     546         reset_sparse_chemical_data(self.data, data)
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/_chemicals.py:1272, in CompiledChemicals._get_index_and_kind(self, key)
#    1270     kind = 0 if isa(index, int) else 1
#    1271 elif isa(key, tuple):
# -> 1272     index = self.indices(key)
#    1273     for i in index:
#    1274         if isa(i, list):
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/_chemicals.py:1177, in CompiledChemicals.indices(self, IDs)
#    1175     return [dct[i] for i in IDs]
#    1176 except KeyError as key_error:
# -> 1177     raise UndefinedChemicalAlias(key_error.args[0])
#
# UndefinedChemicalAlias: 'Cellulose'

# %%
from biosteam import Reaction, ParallelReaction

# example Reaction objects — syntax depends on your biosteam version
r1 = Reaction('Hemicellulose -> Xylose', 'Hemicellulose', 0.941)
r2 = Reaction('Cellulose -> Glucose', 'Cellulose', 0.492)
# secondary decomposition (fractions relative to sugars present)
#r3 = Reaction('Xylose -> 0.25 Furfural + Acetic Acid + 0.10 Formic Acid', 'Xylose', 0.12)
r4 = Reaction('Glucose -> Acetic Acid + Formic Acid', 'Glucose', 0.08)
# combine into reactor
#HTL_reactor.add_reactions([r1, r2, r3, r4])
# Out:
# ---------------------------------------------------------------------------
# UndefinedChemicalAlias                    Traceback (most recent call last)
# Cell In[5], line 8
#       5 r2 = Reaction('Cellulose -> Glucose', 'Cellulose', 0.492)
#       6 # secondary decomposition (fractions relative to sugars present)
#       7 #r3 = Reaction('Xylose -> 0.25 Furfural + Acetic Acid + 0.10 Formic Acid', 'Xylose', 0.12)
# ----> 8 r4 = Reaction('Glucose -> Acetic Acid + Formic Acid', 'Glucose', 0.08)
#       9 # combine into reactor
#      10 #HTL_reactor.add_reactions([r1, r2, r3, r4])
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/reaction/_reaction.py:314, in Reaction.__init__(self, reaction, reactant, X, chemicals, basis, phases, check_mass_balance, check_atomic_balance, correct_atomic_balance, correct_mass_balance)
#     312     self._reactant_index = (phase_index, reactant_index)
#     313 else:
# --> 314     self._stoichiometry = prs.get_stoichiometric_array(reaction, chemicals)
#     315     if reactant is None:
#     316         reactants_index, = self._stoichiometry.negative_index()
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/reaction/_parse.py:26, in get_stoichiometric_array(reaction, chemicals)
#      24 else:
#      25     raise ValueError(f"reaction must be either a str, dict, or array; not a '{type(reaction).__name__}' object")
# ---> 26 stoichiometric_array = dct2arr(stoichiometry_dict, chemicals)
#      27 return stoichiometric_array
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/reaction/_parse.py:50, in dct2arr(dct, chemicals)
#      45         raise ValueError(
#      46             f"'{ID}' is a chemical group; chemical groups cannot be used "
#      47              "in reaction definition"
#      48         )
#      49     if ID not in chemical_index:
# ---> 50         raise UndefinedChemical(ID)
#      51     idct[chemical_index[ID]] = coefficient
#      52 return SparseVector.from_dict(idct, chemicals.size)
#
# UndefinedChemicalAlias: 'AceticAcid'

# %%
import thermosteam as tmo
chemicals = tmo.Chemicals(['H2O', 'H2', 'O2'], cache=True)
tmo.settings.set_thermo(chemicals)
reaction = tmo.Reaction('2H2O,l -> 2H2,g + O2,g', reactant='H2O', X=0.7)
reaction.show()
# Out:
# Reaction (by mol):
# stoichiometry             reactant    X[%]
# H2O,l -> H2,g + 0.5 O2,g  H2O,l      70.00

# %%
import thermosteam as tmo

# example Reaction objects — syntax depends on your biosteam version
r1 = Reaction('Hemicellulose -> Xylose', 'Hemicellulose', 0.941)
r2 = Reaction('Cellulose -> Glucose', 'Cellulose', 0.492)
# secondary decomposition (fractions relative to sugars present)
r3 = Reaction('Xylose -> 0.25 Furfural + Acetic Acid + 0.10 Formic Acid', 'Xylose', 0.12)
r4 = Reaction('Glucose -> Acetic Acid + Formic Acid', 'Glucose', 0.08)
# combine into reactor
#HTL_reactor.add_reactions([r1, r2, r3, r4])
# Out:
# ---------------------------------------------------------------------------
# UndefinedChemicalAlias                    Traceback (most recent call last)
# Cell In[7], line 4
#       1 import thermosteam as tmo
#       3 # example Reaction objects — syntax depends on your biosteam version
# ----> 4 r1 = Reaction('Hemicellulose -> Xylose', 'Hemicellulose', 0.941)
#       5 r2 = Reaction('Cellulose -> Glucose', 'Cellulose', 0.492)
#       6 # secondary decomposition (fractions relative to sugars present)
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/reaction/_reaction.py:314, in Reaction.__init__(self, reaction, reactant, X, chemicals, basis, phases, check_mass_balance, check_atomic_balance, correct_atomic_balance, correct_mass_balance)
#     312     self._reactant_index = (phase_index, reactant_index)
#     313 else:
# --> 314     self._stoichiometry = prs.get_stoichiometric_array(reaction, chemicals)
#     315     if reactant is None:
#     316         reactants_index, = self._stoichiometry.negative_index()
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/reaction/_parse.py:26, in get_stoichiometric_array(reaction, chemicals)
#      24 else:
#      25     raise ValueError(f"reaction must be either a str, dict, or array; not a '{type(reaction).__name__}' object")
# ---> 26 stoichiometric_array = dct2arr(stoichiometry_dict, chemicals)
#      27 return stoichiometric_array
#
# File ~/HTL-Sorghum/venv/lib/python3.12/site-packages/thermosteam/reaction/_parse.py:50, in dct2arr(dct, chemicals)
#      45         raise ValueError(
#      46             f"'{ID}' is a chemical group; chemical groups cannot be used "
#      47              "in reaction definition"
#      48         )
#      49     if ID not in chemical_index:
# ---> 50         raise UndefinedChemical(ID)
#      51     idct[chemical_index[ID]] = coefficient
#      52 return SparseVector.from_dict(idct, chemicals.size)
#
# UndefinedChemicalAlias: 'Hemicellulose'
